# %%
import marisa_trie

data = {
    "red": ["fire", "apple", "sun", "rose", "blood", "stop sign", "chili pepper", "ruby"],
    "blue": ["ocean", "sky", "sapphire", "ice", "blueberry", "calm", "jeans"],
    "green": ["grass", "leaf", "emerald", "frog", "lime", "nature", "growth"],
    "yellow": ["banana", "sunflower", "gold", "lemon", "honey", "cheese"],
    "orange": ["pumpkin", "carrot", "tiger", "sunset", "orange fruit", "flame"],
    "purple": ["grape", "lavender", "amethyst", "royalty", "orchid"],
    "black": ["night", "coal", "shadow", "ink", "obsidian"],
    "white": ["snow", "cloud", "milk", "cotton", "paper"]
}

rt = marisa_trie.Trie(data)

# %%
rt.items()
# Out:
# [('black', 6),
#  ('blue', 7),
#  ('green', 0),
#  ('orange', 1),
#  ('purple', 2),
#  ('red', 3),
#  ('white', 4),
#  ('yellow', 5)]
